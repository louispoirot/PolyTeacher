# %%
# https://ai.google.dev/gemini-api/docs/quickstart?lang=python

import google.generativeai as genai
import os

api_key = "AIzaSyAAAcc2Z1Fi_mEvPg9UEkhwHDd6rFVpWW0"

source_language = "ES"
target_language = "FR"

traduire = "Tengo un gato"

def translate(source, target, text): 

    prompt = f"""
    Traduis {text} qui est en {source} en {target}. La réponse ne doit contenir que la traduction
    """

    model = genai.GenerativeModel("gemini-1.5-flash")
    genai.configure(api_key=api_key)

    response = model.generate_content(prompt)
    return response.text

print(translate(source_language, target_language, traduire))
# Out:
# J'ai un chat.
